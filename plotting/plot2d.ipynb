# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
shape = (256,256,2)
file = "xy_L256_D2_T0_2"
data = np.loadtxt(f"{file}.txt").reshape(shape)

# %%
angles = np.arctan2(data[:,:,0], data[:,:,1])
angles.min(), angles.max(), angles.mean()
# Out:
# (-3.1415688035897977, 3.141575453589795, -1.6907757629670859)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)

im = ax.imshow(angles, cmap="twilight_shifted",interpolation='none')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
cbar = fig.colorbar(im, cax=cax, orientation='vertical', ticks=[-math.pi/2, 0, math.pi / 2])
cbar.set_ticklabels(["-π/2", 0, "π/2"])

fig.tight_layout()
fig.savefig(f"{file}.eps", format="eps", transparent=True,bbox_inches='tight', pad_inches=0)
